# %% [markdown]
# # Project 7 -- Taylor Saunders

# %% [markdown]
# **TA Help:**
# na
#
# **Collaboration:**
# na

# %% [markdown]
# ## Question 1

# %% [markdown]
# Read the file into a DataFrame called myDF.

# %%
import pandas as pd

# %%
myDF = pd.read_parquet('/anvil/projects/tdm/data/whin/weather.parquet')

# %%
myDF.head()
# Out:
#    station_id  latitude  longitude             name      observation_time  \
# 0           1  40.93894  -86.47418  WHIN001-PULA001  2019-07-10T04:00:00Z
# 1           1  40.93894  -86.47418  WHIN001-PULA001  2019-07-10T04:15:00Z
# 2           1  40.93894  -86.47418  WHIN001-PULA001  2019-07-11T04:00:00Z
# 3           1  40.93894  -86.47418  WHIN001-PULA001  2019-07-11T04:15:00Z
# 4           1  40.93894  -86.47418  WHIN001-PULA001  2019-07-11T04:30:00Z
#
#    temperature  temperature_high  temperature_low  humidity  solar_radiation  \
# 0         70.0              71.0             70.0      83.0              NaN
# 1         69.0              70.0             69.0      84.0              NaN
# 2         76.0              77.0             76.0      76.0              NaN
# 3         76.0              76.0             76.0      77.0              NaN
# 4         76.0              76.0             76.0      77.0              NaN
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
myDF.head()
# Out:
#    station_id  latitude  longitude             name          observation_time  \
# 0           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-10 04:00:00+00:00
# 1           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-10 04:15:00+00:00
# 2           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:00:00+00:00
# 3           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:15:00+00:00
# 4           1  40.93894  -86.47418  WHIN001-PULA001 2019-07-11 04:30:00+00:00
#
#    temperature  temperature_high  temperature_low  humidity  solar_radiation  \
# 0         70.0              71.0             70.0      83.0              NaN
# 1         69.0              70.0             69.0      84.0              NaN
# 2         76.0              77.0             76.0      76.0              NaN
# 3         76.0              76.0             76.0      77.0              NaN
# 4         76.0              76.0             76.0      77.0              NaN
#
# ...

# %% [markdown]
# Convert the observation_time column to into a datetime type.

# %%
myDF['observation_time'] = pd.to_datetime(myDF['observation_time'])

# %% [markdown]
# Create 3 new columns for the year, month and day, based on the column observation_time.

# %%
myDF['year'] = myDF['observation_time'].dt.year

# %%
myDF['month'] = myDF['observation_time'].dt.month

# %%
myDF['day'] = myDF['observation_time'].dt.day

# %% [markdown]
# For a given station_id, calculate the average month-and-year-pair temperatures (from the column temperature) for that station_id. Try this for a few different station_id values.

# %%
my_station_id_1 = 1

# %%
myDF[myDF['station_id'] == my_station_id].shape
# Out:
# (71733, 29)

# %%
myDF[myDF['station_id'] == my_station_id].groupby(['year', 'month'])['temperature'].mean()
# Out:
# year  month
# 2019  7         1.699000
#       8        58.450756
#       9        68.906912
#       10       53.950605
#       11       35.828114
#       12       34.838319
# 2020  1        32.782521
#       2        30.199713
#       3        42.102590
#       4        48.237153
#       5        60.180444
#       6        73.109375
#       7        76.111970
#       8        71.325480
#       9        64.010424
#       10       51.814454
#       11       46.175652
#       12       32.706989
# 2021  1        29.468571
#       2        21.116115
#       3        44.176194
#       4        50.613834
#       5        59.466555
#       6        73.381730
#       7        72.553822
# Name: temperature, dtype: float64

# %%
my_station_id_2 = 45

# %%
myDF[myDF['station_id'] == my_station_id_2].groupby(['year', 'month'])['temperature'].mean()
# Out:
# year  month
# 2019  9        70.880137
#       10       54.831540
#       11       36.808000
#       12       36.176807
# 2020  1        33.625420
#       2        31.324353
#       3        43.333782
#       4        49.493922
#       5        60.592468
#       6        73.389624
#       7        75.854833
#       8        71.523729
#       9        64.795897
#       10       52.803025
#       11       47.208623
#       12       33.464046
# 2021  1        30.344758
#       2        22.276889
#       3        45.290420
#       4        52.344792
#       5        60.578965
#       6        73.982286
#       7        72.756445
# Name: temperature, dtype: float64

# %% [markdown]
# Now write a function called get_avg_temp that takes one station_id as input and returns the average month-and-year-pair temperatures (associated with that specific station_id). Make sure that the results of your function match with your work from question 1c.

# %%
def get_avg_temp(station_id):
    """
    returns: average month-and-year-pair temperatres associated with that specific station_id
    """
    #myDF = pd.read_csv(file_location, header=None, names=column_title_list)
    myresult = myDF[myDF['station_id'] == my_station_id_2].groupby(['year', 'month'])['temperature'].mean()
    return myresult

# %%
get_avg_temp(1)
# Out:
# year  month
# 2019  9        70.880137
#       10       54.831540
#       11       36.808000
#       12       36.176807
# 2020  1        33.625420
#       2        31.324353
#       3        43.333782
#       4        49.493922
#       5        60.592468
#       6        73.389624
#       7        75.854833
#       8        71.523729
#       9        64.795897
#       10       52.803025
#       11       47.208623
#       12       33.464046
# 2021  1        30.344758
#       2        22.276889
#       3        45.290420
#       4        52.344792
#       5        60.578965
#       6        73.982286
#       7        72.756445
# Name: temperature, dtype: float64

# %% [markdown]
# ## Question 2

# %% [markdown]
# For this function, be sure to import matplotlib.pyplot.
#
# We will use the function from question 1d to make some line plots.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# For a given station_id, create a line plot, with one line for each year. Try this for a few different station_id values.

# %%
myresults = myDF[myDF['station_id'] == my_station_id_1].groupby(['year', 'month'])['temperature'].mean()

# %%
myresults.unstack(0).plot(kind = 'line', marker ='o')
plt.title(f'Average monthly temperatures for given station_id and all month-and-year pairs')
plt.xlabel('Month')
plt.ylabel('Avergae temperature')
plt.xticks( range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title = 'Year')
plt.grid(True)
plt.show()

# %% [markdown]
# Now that you are sure your analysis from 2a works well, wrap your work from question 2a into a function that takes a station_id as input, and creates a line plot, with one line for each year (for the average month-and-year-pair temperatures from that station_id).

# %%
def get_avg_temp_plot(station_id):
    """
    returns: line plot of average month-and-year-pair temperatres associated with that specific station_id
    """
    #myDF = pd.read_csv(file_location, header=None, names=column_title_list)
    myresult = myDF[myDF['station_id'] == my_station_id_2].groupby(['year', 'month'])['temperature'].mean()
    myplot = myresult.unstack(0).plot(kind = 'line', marker ='o')
    plt.title(f'Average monthly temperatures for given station_id and all month-and-year pairs')
    return myplot

# %%
get_avg_temp_plot(1)
# Out:
# <Axes: title={'center': 'Average monthly temperatures for given station_id and all month-and-year pairs'}, xlabel='month'>

# %%
get_avg_temp_plot(42)
# Out:
# <Axes: title={'center': 'Average monthly temperatures for given station_id and all month-and-year pairs'}, xlabel='month'>

# %% [markdown]
# ## Question 3

# %% [markdown]
# Revisit the function from question 1d, to find the maximum temperature (instead of the average temperature) in each month-and-year-pair, for a given station. As before, you should test this for several examples before you build the function, and then make sure your function matches your examples.

# %%
def get_max_temp(station_id):
    """
    returns: maximum month-and-year-pair temperatres associated with that specific station_id
    """
    #myDF = pd.read_csv(file_location, header=None, names=column_title_list)
    myresult = myDF[myDF['station_id'] == my_station_id_2].groupby(['year', 'month'])['temperature'].max()
    return myresult

# %%
get_max_temp(1)
# Out:
# year  month
# 2019  9        93.0
#       10       91.0
#       11       57.0
#       12       64.0
# 2020  1        61.0
#       2        60.0
#       3        68.0
#       4        79.0
#       5        88.0
#       6        92.0
#       7        93.0
#       8        91.0
#       9        88.0
#       10       84.0
#       11       78.0
#       12       63.0
# 2021  1        46.0
#       2        61.0
#       3        73.0
#       4        84.0
#       5        88.0
#       6        93.0
#       7        87.0
# Name: temperature, dtype: float64

# %%
get_max_temp(42)
# Out:
# year  month
# 2019  9        93.0
#       10       91.0
#       11       57.0
#       12       64.0
# 2020  1        61.0
#       2        60.0
#       3        68.0
#       4        79.0
#       5        88.0
#       6        92.0
#       7        93.0
#       8        91.0
#       9        88.0
#       10       84.0
#       11       78.0
#       12       63.0
# 2021  1        46.0
#       2        61.0
#       3        73.0
#       4        84.0
#       5        88.0
#       6        93.0
#       7        87.0
# Name: temperature, dtype: float64

# %% [markdown]
# Revisit the function from question 2b, to make a function that takes one station_id as input and it creates a bar plot (instead of a line plot), depicting the maximum temperature in each month-and-year-pair (instead of the average temperature).

# %%
myresult_max = myDF[myDF['station_id'] == my_station_id_2].groupby(['year', 'month'])['temperature'].max()

# %%
myresult_max.unstack(0).plot(kind = 'bar')
plt.title(f'Average monthly temperatures for given station_id and all month-and-year pairs')
plt.xlabel('Month')
plt.ylabel('Avergae temperature')
plt.xticks( range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend(title = 'Year')
plt.grid(True)
plt.show()

# %%
def get_max_temp(station_id):
    """
    returns: box plot of max month-and-year-pair temperatres associated with that specific station_id
    """
    #myDF = pd.read_csv(file_location, header=None, names=column_title_list)
    myresult_max = myDF[myDF['station_id'] == my_station_id_2].groupby(['year', 'month'])['temperature'].max()
    max_bar = myresult_max.unstack(0).plot(kind = 'bar')
    plt.title(f'Average monthly temperatures for given station_id and all month-and-year pairs')
    plt.xlabel('Month')
    plt.ylabel('Avergae temperature')
    plt.xticks( range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
    plt.legend(title = 'Year')
    plt.grid(True)
    plt.show()
    return max_bar

# %%
get_max_temp(1)
# Out:
# <Axes: title={'center': 'Average monthly temperatures for given station_id and all month-and-year pairs'}, xlabel='Month', ylabel='Avergae temperature'>

# %%
get_max_temp(42)
# Out:
# <Axes: title={'center': 'Average monthly temperatures for given station_id and all month-and-year pairs'}, xlabel='Month', ylabel='Avergae temperature'>

# %% [markdown]
# ## Question 4

# %% [markdown]
# For a given station_id, create a box plot that shows the month-by-month wind speeds in 2020 for that specified station_id. Try this for a few different station_id values.

# %%
my_station_id = 1
myyear = 2020

# %%
myresults = myDF[(myDF['station_id'] == my_station_id) & (myDF['year'] == myyear)]

# %%
myresults.boxplot(column = 'wind_speed_mph', by = 'month')
# Out:
# <Axes: title={'center': 'wind_speed_mph'}, xlabel='month'>

# %% [markdown]
# Write a function that takes a year (not necessarily 2020) and a station_id as inputs, and the function creates a box plot about the month-by-month wind speeds in that specific year (not necessarily 2020), at the specified station_id.

# %%
def get_wind(station_id, myyear):
    """
    returns: creates a box plot about the month-by-month wind speeds in that specific year at the specified station_id.
    """
    myresults = myDF[(myDF['station_id'] == my_station_id) & (myDF['year'] == myyear)]
    wind_box = myresults.boxplot(column = 'wind_speed_mph', by = 'month')
    return wind_box

# %%
get_wind(1, 2020)
# Out:
# <Axes: title={'center': 'wind_speed_mph'}, xlabel='month'>

# %%
get_wind(42, 2019)
# Out:
# <Axes: title={'center': 'wind_speed_mph'}, xlabel='month'>

# %% [markdown]
# ## Question 5

# %% [markdown]
# Explore the dateset and find something interesting, like (for instance) something about the wind speed, pressure, soil temperature, etc., and do some analysis. Make a visualization that shows one or more plots about your analysis. Wrap the work 5a and 5b into a function that can be used to create the visualizations in a systematic way, and test the function with the same inputs used in 5a and 5b.

# %%
def get_avg_pressure_plot(station_id):
    """
    returns: line plot of average month-and-year-pair pressures associated with that specific station_id
    """
    #myDF = pd.read_csv(file_location, header=None, names=column_title_list)
    myresult = myDF[myDF['station_id'] == my_station_id_2].groupby(['year', 'month'])['pressure'].mean()
    myplot = myresult.unstack(0).plot(kind = 'line', marker ='o')
    plt.xlabel('Month')
    plt.ylabel('Avergae pressure')
    plt.xticks( range(1,13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
    plt.legend(title = 'Year')
    plt.grid(True)
    plt.title(f'Average monthly pressure for given station_id and all month-and-year pairs')
    return myplot

# %%
get_avg_pressure_plot(1)
# Out:
# <Axes: title={'center': 'Average monthly pressure for given station_id and all month-and-year pairs'}, xlabel='Month', ylabel='Avergae pressure'>

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
